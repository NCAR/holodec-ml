# %%
import holodecml.FourierOpticsLib as FO
from scipy.fftpack import fft2, ifft2, fftshift
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from holodecml.data import load_train_patches, load_raw_datasets

# %%
path_data = "/glade/p/cisl/aiml/ai4ess_hackathon/holodec/"
num_particles = "medium"
output_cols = ["x", "y", "z", "d", "hid"]
scaler_out = MinMaxScaler()
subset = False
rad = 32

# %%
train_inputs,\
train_hids,\
train_outputs,\
valid_inputs,\
valid_hids,\
valid_outputs = load_train_patches(path_data,
                                   num_particles,
                                   output_cols,
                                   scaler_out,
                                   subset,
                                   rad)

# %%
train_inputs.shape
# Out:
# (1478998, 65, 65)

# %%
image = train_inputs[0]
image_fft2 = fft2(image)

# %%
plt.pcolormesh(image)

# %%
train_inputs_fft = fft2(train_inputs)
train_inputs_fft.shape
# Out:
# (1478998, 65, 65)

# %%
plt.pcolormesh(np.abs(train_inputs_fft[0].real), norm=LogNorm())

# %%
plt.pcolormesh(np.abs(image_fft2.real), norm=LogNorm())

# %%
train_inputs_raw,\
train_outputs_raw = load_raw_datasets(path_data,
                                  num_particles,
                                  'train',
                                  output_cols,
                                  subset)

# %%
image_raw = train_inputs_raw[0]
image_raw_fft2 = fft2(image_raw)
